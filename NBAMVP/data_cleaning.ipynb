# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/11.5 MB 15.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.5 MB 17.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 16.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.6 MB 17.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.6 MB 18.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 17.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank               Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1        Julius Erving   30  PHI   28.0    454.0      690
# 1             1    2           Larry Bird   24  BOS   20.0    423.0      690
# 2             2    3  Kareem Abdul-Jabbar   33  LAL    8.0    286.0      690
# 3             3    4         Moses Malone   25  HOU    8.0    180.0      690
# 4             4    5        George Gervin   28  SAS    1.0     83.0      690
# ..          ...  ...                  ...  ...  ...    ...      ...      ...
# 705           4    5        Jalen Brunson   27  NYK    0.0    142.0      990
# 706           5    6         Jayson Tatum   25  BOS    0.0     86.0      990
# 707           6    7      Anthony Edwards   22  MIN    0.0     18.0      990
# 708           7    8     Domantas Sabonis   27  SAC    0.0      3.0      990
# 709           8    9         Kevin Durant   35  PHO    0.0      1.0      990
#
# ...

# %%
mvps = mvps[["Player", "Pts Won", "Pts Max", "Share", "Year"]]

# %%
mvps
# Out:
#                   Player  Pts Won  Pts Max  Share  Year
# 0          Julius Erving    454.0      690  0.658  1981
# 1             Larry Bird    423.0      690  0.613  1981
# 2    Kareem Abdul-Jabbar    286.0      690  0.414  1981
# 3           Moses Malone    180.0      690  0.261  1981
# 4          George Gervin     83.0      690  0.120  1981
# ..                   ...      ...      ...    ...   ...
# 705        Jalen Brunson    142.0      990  0.143  2024
# 706         Jayson Tatum     86.0      990  0.087  2024
# 707      Anthony Edwards     18.0      990  0.018  2024
# 708     Domantas Sabonis      3.0      990  0.003  2024
# 709         Kevin Durant      1.0      990  0.001  2024
#
# [710 rows x 5 columns]

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk               Player  Age Team  Pos    G   GS    MP  \
# 0               0    1       Adrian Dantley   25  UTA   SF   80  NaN  42.7
# 1               1    2         Moses Malone   25  HOU    C   80  NaN  40.6
# 2               2    3        George Gervin   28  SAS   SG   82   82  33.7
# 3               3    4  Kareem Abdul-Jabbar   33  LAL    C   80  NaN  37.2
# 4               4    5       David Thompson   26  DEN   SG   77  NaN  34.0
# ...           ...  ...                  ...  ...  ...  ...  ...  ...   ...
# 24274         754  569       Ron Harper Jr.   23  TOR   PF    1    0   4.0
# 24275         755  570       Justin Jackson   28  MIN   SF    2    0   0.5
# 24276         756  571    Dmytro Skapintsev   25  NYK    C    2    0   1.0
# 24277         757  572        Javonte Smart   24  PHI   PG    1    0   1.0
# 24278         758  NaN       League Average  NaN  NaN  NaN  NaN  NaN   NaN
#
# ...

# %%
del players["Unnamed: 0"]

# %%
del players["Rk"]

# %%
del players["Awards"]

# %%
players
# Out:
#                     Player  Age Team  Pos    G   GS    MP    FG   FGA   FG%  \
# 0           Adrian Dantley   25  UTA   SF   80  NaN  42.7  11.4  20.3  .559
# 1             Moses Malone   25  HOU    C   80  NaN  40.6  10.1  19.3  .522
# 2            George Gervin   28  SAS   SG   82   82  33.7  10.4  21.1  .492
# 3      Kareem Abdul-Jabbar   33  LAL    C   80  NaN  37.2  10.5  18.2  .574
# 4           David Thompson   26  DEN   SG   77  NaN  34.0   9.5  18.8  .506
# ...                    ...  ...  ...  ...  ...  ...   ...   ...   ...   ...
# 24274       Ron Harper Jr.   23  TOR   PF    1    0   4.0   0.0   0.0   NaN
# 24275       Justin Jackson   28  MIN   SF    2    0   0.5   0.0   0.0   NaN
# 24276    Dmytro Skapintsev   25  NYK    C    2    0   1.0   0.0   0.5  .000
# 24277        Javonte Smart   24  PHI   PG    1    0   1.0   0.0   0.0   NaN
# 24278       League Average  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN  .474
#
# ...

# %%
players = players[~players["Player"].str.contains("Player")]

# %%
players = players[~players["Player"].str.contains("League Average")]

# %%
players
# Out:
#                     Player Age Team Pos   G   GS    MP    FG   FGA   FG%  ...  \
# 0           Adrian Dantley  25  UTA  SF  80  NaN  42.7  11.4  20.3  .559  ...
# 1             Moses Malone  25  HOU   C  80  NaN  40.6  10.1  19.3  .522  ...
# 2            George Gervin  28  SAS  SG  82   82  33.7  10.4  21.1  .492  ...
# 3      Kareem Abdul-Jabbar  33  LAL   C  80  NaN  37.2  10.5  18.2  .574  ...
# 4           David Thompson  26  DEN  SG  77  NaN  34.0   9.5  18.8  .506  ...
# ...                    ...  ..  ...  ..  ..  ...   ...   ...   ...   ...  ...
# 24273          Danny Green  36  PHI  SG   2    0   9.0   0.0   1.0  .000  ...
# 24274       Ron Harper Jr.  23  TOR  PF   1    0   4.0   0.0   0.0   NaN  ...
# 24275       Justin Jackson  28  MIN  SF   2    0   0.5   0.0   0.0   NaN  ...
# 24276    Dmytro Skapintsev  25  NYK   C   2    0   1.0   0.0   0.5  .000  ...
# 24277        Javonte Smart  24  PHI  PG   1    0   1.0   0.0   0.0   NaN  ...
#
# ...

# %%
players["Player"] = players["Player"].str.replace("*", "", regex=False)

# %%
players.head(50)
# Out:
#                     Player Age Team Pos   G   GS    MP    FG   FGA   FG%  ...  \
# 0           Adrian Dantley  25  UTA  SF  80  NaN  42.7  11.4  20.3  .559  ...
# 1             Moses Malone  25  HOU   C  80  NaN  40.6  10.1  19.3  .522  ...
# 2            George Gervin  28  SAS  SG  82   82  33.7  10.4  21.1  .492  ...
# 3      Kareem Abdul-Jabbar  33  LAL   C  80  NaN  37.2  10.5  18.2  .574  ...
# 4           David Thompson  26  DEN  SG  77  NaN  34.0   9.5  18.8  .506  ...
# 5            Otis Birdsong  25  KCK  SG  71  NaN  36.5  10.0  18.4  .544  ...
# 6            Julius Erving  30  PHI  SF  82   82  35.0   9.7  18.6  .521  ...
# 7            Mike Mitchell  25  CLE  SF  82   82  39.0  10.4  21.8  .476  ...
# 8            World B. Free  27  GSW  SG  65  NaN  36.5   7.9  17.8  .446  ...
# 9             Alex English  27  DEN  SF  81  NaN  38.2   9.5  19.2  .494  ...
# 10           Jamaal Wilkes  27  LAL  SF  81  NaN  37.4   9.7  18.5  .526  ...
# ...

# %%
players.groupby(["Player", "Year"]).get_group(("Greg Anderson", 1991))
# Out:
#              Player Age Team Pos   G GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 4349  Greg Anderson  26  3TM  PF  68  2  13.6  1.7  4.0   .430  ...  1.4  3.3
# 4350  Greg Anderson  26  MIL  PF  26  0   9.5  1.0  2.8   .370  ...  1.0  1.9
# 4351  Greg Anderson  26  NJN  PF   1  0  18.0  4.0  4.0  1.000  ...  4.0  2.0
# 4352  Greg Anderson  26  DEN  PF  41  2  16.1  2.1  4.7   .440  ...  1.6  4.1
#
#       TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 4349  4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 4350  2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 4351  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 4352  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %%
def single_row(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Team"].str.contains("TM")]
        row["Team"] = df.iloc[-1,:]["Team"]
        return row

players = players.groupby(["Player", "Year"]).apply(single_row)
# Out:
# C:\Users\salya\AppData\Local\Temp\ipykernel_30488\708940378.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Age Team Pos   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1986 2110      A.C. Green  22  LAL  PF  82   1  18.8  2.5   4.7
#               1987 2405      A.C. Green  23  LAL  PF  79  72  28.4  4.0   7.4
#               1988 2797      A.C. Green  24  LAL  PF  82  64  32.1  3.9   7.8
#               1989 3215      A.C. Green  25  LAL  PF  82  82  30.6  4.9   9.2
#               1990 3670      A.C. Green  26  LAL  PF  82  82  33.0  4.7   9.8
#               1991 4218      A.C. Green  27  LAL  PF  82  21  26.4  3.1   6.6
#               1992 4586      A.C. Green  28  LAL  PF  82  53  35.4  4.7   9.8
#               1993 5071      A.C. Green  29  LAL  PF  82  55  34.4  4.6   8.6
#               1994 5501      A.C. Green  30  PHO  PF  82  55  34.5  5.7  11.3
#               1995 6057      A.C. Green  31  PHO  SF  82  52  32.8  3.8   7.5
#               1996 6637      A.C. Green  32  PHO  SF  82  36  25.8  2.6   5.4
# ...

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players
# Out:
#                Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  ORB  \
# 2110       A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  2.0
# 2405       A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  2.7
# 2797       A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  3.0
# 3215       A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  3.1
# 3670       A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  3.2
# ...               ...  ..  ...  ..  ..  ..   ...  ...  ...   ...  ...  ...
# 9939   Željko Rebrača  29  DET   C  74   4  15.9  2.6  5.1  .505  ...  1.1
# 10441  Željko Rebrača  30  DET   C  30  12  16.3  2.7  4.8  .552  ...  0.9
# 11126  Željko Rebrača  31  ATL   C  24   2  11.4  1.4  3.2  .442  ...  1.0
# 11647  Željko Rebrača  32  LAC   C  58   2  16.0  2.3  4.0  .568  ...  0.8
# 12260  Željko Rebrača  33  LAC   C  29   2  14.2  1.8  3.3  .542  ...  0.4
#
#        DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
players.to_csv("tempplay.csv")

# %%
players.head()
# Out:
#           Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  ORB  DRB  \
# 2110  A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  2.0  2.7
# 2405  A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  2.7  5.1
# 2797  A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  3.0  5.7
# 3215  A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  3.1  5.9
# 3670  A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  3.2  5.5
#
#       TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 2110  4.6  0.7  0.6  0.6  1.2  2.8   6.4  1986
# 2405  7.8  1.1  0.9  1.0  1.3  2.2  10.8  1987
# 2797  8.7  1.1  1.1  0.5  1.5  2.5  11.4  1988
# 3215  9.0  1.3  1.1  0.7  1.5  2.1  13.3  1989
# 3670  8.7  1.1  0.8  0.6  1.4  2.5  12.9  1990
#
# [5 rows x 30 columns]

# %%
combined = players.merge(mvps, how="outer", on=["Player", "Year"])

# %%
combined
# Out:
#                Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  AST  \
# 0          A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  0.7
# 1          A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  1.1
# 2          A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  1.1
# 3          A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  1.3
# 4          A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  1.1
# ...               ...  ..  ...  ..  ..  ..   ...  ...  ...   ...  ...  ...
# 19066  Željko Rebrača  29  DET   C  74   4  15.9  2.6  5.1  .505  ...  0.5
# 19067  Željko Rebrača  30  DET   C  30  12  16.3  2.7  4.8  .552  ...  0.3
# 19068  Željko Rebrača  31  ATL   C  24   2  11.4  1.4  3.2  .442  ...  0.3
# 19069  Željko Rebrača  32  LAC   C  58   2  16.0  2.3  4.0  .568  ...  0.4
# 19070  Željko Rebrača  33  LAC   C  29   2  14.2  1.8  3.3  .542  ...  0.3
#
#        STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max Share
# ...

# %%
combined.to_csv("tempcombined.csv")

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined
# Out:
#                 Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  AST  \
# 0           A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  0.7
# 1           A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  1.1
# 2           A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  1.1
# 3           A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  1.3
# 4           A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  1.1
# ...                ...  ..  ...  ..  ..  ..   ...  ...  ...   ...  ...  ...
# 16942  Žarko Čabarkapa  24  GSW  PF  61   0   8.3  1.1  2.9  .385  ...  0.3
# 16943   Željko Rebrača  29  DET   C  74   4  15.9  2.6  5.1  .505  ...  0.5
# 16944   Željko Rebrača  30  DET   C  30  12  16.3  2.7  4.8  .552  ...  0.3
# 16945   Željko Rebrača  32  LAC   C  58   2  16.0  2.3  4.0  .568  ...  0.4
# 16946   Željko Rebrača  33  LAC   C  29   2  14.2  1.8  3.3  .542  ...  0.3
#
# ...

# %%
teams = pd.read_csv("teams.csv")

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  62  20  .756     —  109.9  104.0   6.05  1981
# 1              1  62  20  .756     —  111.7  103.8   7.76  1981
# 2              2  50  32  .610  12.0  107.9  106.3   2.00  1981
# 3              3  39  43  .476  23.0  105.6  105.6   0.42  1981
# 4              4  24  58  .293  38.0  106.9  113.0  -5.15  1981
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1399          13  50  32  .610     —  117.9  115.6   2.30  2024
# 1400          14  49  33  .598   1.0  115.1  110.7   4.46  2024
# 1401          15  41  41  .500   9.0  114.3  113.2   1.24  2024
# 1402          16  27  55  .329  23.0  105.8  112.8  -6.57  2024
# 1403          17  22  60  .268  28.0  112.1  118.6  -5.80  2024
#
#                        Team
# 0           Boston Celtics*
# 1       Philadelphia 76ers*
# 2          New York Knicks*
# 3        Washington Bullets
# 4           New Jersey Nets
# ...

# %%
teams.head(30)
# Out:
#     Unnamed: 0                 W                 L              W/L%  \
# 0            0                62                20              .756
# 1            1                62                20              .756
# 2            2                50                32              .610
# 3            3                39                43              .476
# 4            4                24                58              .293
# 5            5  Central Division  Central Division  Central Division
# 6            6                60                22              .732
# 7            7                45                37              .549
# 8            8                44                38              .537
# 9            9                31                51              .378
# 10          10                28                54              .341
# 11          11                21                61              .256
# 12           0  Midwest Division  Midwest Division  Midwest Division
# ...

# %%
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)
# Out:
# C:\Users\salya\AppData\Local\Temp\ipykernel_30488\390097362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
teams.head(5)
# Out:
#    Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0           0  62  20  .756     —  109.9  104.0   6.05  1981
# 1           1  62  20  .756     —  111.7  103.8   7.76  1981
# 2           2  50  32  .610  12.0  107.9  106.3   2.00  1981
# 3           3  39  43  .476  23.0  105.6  105.6   0.42  1981
# 4           4  24  58  .293  38.0  106.9  113.0  -5.15  1981
#
#                  Team
# 0      Boston Celtics
# 1  Philadelphia 76ers
# 2     New York Knicks
# 3  Washington Bullets
# 4     New Jersey Nets

# %%
df = pd.read_csv('nicknames.txt', delimiter=',')  
df.to_csv('nicknames.csv', index=False)

# %%
nicknames = {}

with open("nicknames.csv") as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['Abbreviation,Name\n',
#  'ATL,Atlanta Hawks\n',
#  'BRK,Brooklyn Nets\n',
#  'BKN,Brooklyn Nets\n',
#  'BOS,Boston Celtics\n',
#  'CHA,Charlotte Bobcats\n',
#  'CHH,Charlotte Hornets\n',
#  'CHO,Charlotte Hornets\n',
#  'CHI,Chicago Bulls\n',
#  'CLE,Cleveland Cavaliers\n',
#  'DAL,Dallas Mavericks\n',
#  'DEN,Denver Nuggets\n',
#  'DET,Detroit Pistons\n',
#  'GSW,Golden State Warriors\n',
#  'HOU,Houston Rockets\n',
#  'IND,Indiana Pacers\n',
#  'LAC,Los Angeles Clippers\n',
#  'LAL,Los Angeles Lakers\n',
#  'MEM,Memphis Grizzlies\n',
#  'MIA,Miami Heat\n',
#  'MIL,Milwaukee Bucks\n',
#  'MIN,Minnesota Timberwolves\n',
#  'NJN,New Jersey Nets\n',
#  'NOH,New Orleans Hornets\n',
#  'NOP,New Orleans Pelicans\n',
#  'NOK,New Orleans/Oklahoma City Hornets\n',
#  'NYK,New York Knicks\n',
#  'OKC,Oklahoma City Thunder\n',
#  'ORL,Orlando Magic\n',
#  'PHI,Philadelphia 76ers\n',
#  'PHX,Phoenix Suns\n',
#  'PHO,Phoenix Suns\n',
#  'POR,Portland Trail Blazers\n',
# ...

# %%
for line in lines[1:]:
    abbrev,name = line.replace("\n", "").split(",")
    nicknames[abbrev] = name

# %%
nicknames
# Out:
# {'ATL': 'Atlanta Hawks',
#  'BRK': 'Brooklyn Nets',
#  'BKN': 'Brooklyn Nets',
#  'BOS': 'Boston Celtics',
#  'CHA': 'Charlotte Bobcats',
#  'CHH': 'Charlotte Hornets',
#  'CHO': 'Charlotte Hornets',
#  'CHI': 'Chicago Bulls',
#  'CLE': 'Cleveland Cavaliers',
#  'DAL': 'Dallas Mavericks',
#  'DEN': 'Denver Nuggets',
#  'DET': 'Detroit Pistons',
#  'GSW': 'Golden State Warriors',
#  'HOU': 'Houston Rockets',
#  'IND': 'Indiana Pacers',
#  'LAC': 'Los Angeles Clippers',
#  'LAL': 'Los Angeles Lakers',
#  'MEM': 'Memphis Grizzlies',
#  'MIA': 'Miami Heat',
#  'MIL': 'Milwaukee Bucks',
#  'MIN': 'Minnesota Timberwolves',
#  'NJN': 'New Jersey Nets',
#  'NOH': 'New Orleans Hornets',
#  'NOP': 'New Orleans Pelicans',
#  'NOK': 'New Orleans/Oklahoma City Hornets',
#  'NYK': 'New York Knicks',
#  'OKC': 'Oklahoma City Thunder',
#  'ORL': 'Orlando Magic',
#  'PHI': 'Philadelphia 76ers',
#  'PHX': 'Phoenix Suns',
#  'PHO': 'Phoenix Suns',
#  'POR': 'Portland Trail Blazers',
# ...

# %%
combined["Tm"] = combined["Team"].map(nicknames)

# %%
combined.head(5)
# Out:
#        Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  0.6  0.6  1.2
# 1  A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  0.9  1.0  1.3
# 2  A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  1.1  0.5  1.5
# 3  A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  1.1  0.7  1.5
# 4  A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  0.8  0.6  1.4
#
#     PF   PTS  Year Pts Won Pts Max Share                  Tm
# 0  2.8   6.4  1986     0.0     0.0   0.0  Los Angeles Lakers
# 1  2.2  10.8  1987     0.0     0.0   0.0  Los Angeles Lakers
# 2  2.5  11.4  1988     0.0     0.0   0.0  Los Angeles Lakers
# 3  2.1  13.3  1989     0.0     0.0   0.0  Los Angeles Lakers
# 4  2.5  12.9  1990     0.0     0.0   0.0  Los Angeles Lakers
#
# [5 rows x 34 columns]

# %%
teams.rename(columns={'Team': 'Tm'}, inplace=True)
# Out:
# C:\Users\salya\AppData\Local\Temp\ipykernel_30488\2590539626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams.rename(columns={'Team': 'Tm'}, inplace=True)

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  62  20  .756     —  109.9  104.0   6.05  1981
# 1              1  62  20  .756     —  111.7  103.8   7.76  1981
# 2              2  50  32  .610  12.0  107.9  106.3   2.00  1981
# 3              3  39  43  .476  23.0  105.6  105.6   0.42  1981
# 4              4  24  58  .293  38.0  106.9  113.0  -5.15  1981
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1399          13  50  32  .610     —  117.9  115.6   2.30  2024
# 1400          14  49  33  .598   1.0  115.1  110.7   4.46  2024
# 1401          15  41  41  .500   9.0  114.3  113.2   1.24  2024
# 1402          16  27  55  .329  23.0  105.8  112.8  -6.57  2024
# 1403          17  22  60  .268  28.0  112.1  118.6  -5.80  2024
#
#                         Tm
# 0           Boston Celtics
# 1       Philadelphia 76ers
# 2          New York Knicks
# 3       Washington Bullets
# 4          New Jersey Nets
# ...                    ...
# ...

# %%
stats = combined.merge(teams, how="outer", on=["Tm", "Year"])

# %%
stats
# Out:
#                Player Age Team Pos   G   GS    MP   FG   FGA   FG%  ... Share  \
# 0         Art Collins  26  ATL  SG  29  NaN  13.6  1.2   3.4  .354  ...   NaN
# 1       Charlie Criss  32  ATL  PG  66  NaN  25.9  3.3   7.3  .454  ...   NaN
# 2       Craig Shelton  23  ATL  SF  55  NaN  10.7  1.8   4.0  .457  ...   NaN
# 3      Dan Roundfield  27  ATL  PF  63  NaN  33.8  6.8  12.8  .527  ...   NaN
# 4       Eddie Johnson  25  ATL  SG  75  NaN  35.9  7.6  15.1  .504  ...   NaN
# ...               ...  ..  ...  ..  ..  ...   ...  ...   ...   ...  ...   ...
# 19075  Mark Olberding  28  KCK  PF  81   62  28.1  3.3   6.5  .502  ...   NaN
# 19076    Mike Woodson  26  KCK  SG  78    3  25.6  6.8  13.7  .496  ...   NaN
# 19077     Otis Thorpe  22  KCK  PF  82   23  23.4  5.0   8.4  .600  ...   NaN
# 19078  Pete Verhoeven  25  KCK  PF  54    0   6.8  0.9   2.0  .472  ...   NaN
# 19079    Reggie Theus  27  KCK  SG  82   80  31.0  6.1  12.5  .487  ...   NaN
#
# ...

# %%
stats.to_csv("stats.csv")

# %%
stats
# Out:
#                Player Age Team Pos   G   GS    MP   FG   FGA   FG%  ...  \
# 0         Art Collins  26  ATL  SG  29  NaN  13.6  1.2   3.4  .354  ...
# 1       Charlie Criss  32  ATL  PG  66  NaN  25.9  3.3   7.3  .454  ...
# 2       Craig Shelton  23  ATL  SF  55  NaN  10.7  1.8   4.0  .457  ...
# 3      Dan Roundfield  27  ATL  PF  63  NaN  33.8  6.8  12.8  .527  ...
# 4       Eddie Johnson  25  ATL  SG  75  NaN  35.9  7.6  15.1  .504  ...
# ...               ...  ..  ...  ..  ..  ...   ...  ...   ...   ...  ...
# 19034   Steve Johnson  25  KCK   C  79   21  19.5  4.7   7.5  .624  ...
# 19035      Swen Nater  33  SDC   C   7    0   7.3  0.9   2.9  .300  ...
# 19036  Terry Cummings  21  SDC  PF  70   69  36.2  9.8  18.7  .523  ...
# 19037    Tom Chambers  23  SDC  PF  79   79  33.7  6.6  13.9  .472  ...
# 19038     Bill Walton  31  SDC   C  55   46  26.8  5.2   9.4  .556  ...
#
#        Share             Tm Unnamed: 0    W    L  W/L%    GB   PS/G   PA/G  \
# ...

# %%
players
# Out:
#                 Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  ORB  \
# 2110        A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  2.0
# 2405        A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  2.7
# 2797        A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  3.0
# 3215        A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  3.1
# 3670        A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  3.2
# ...                ...  ..  ...  ..  ..  ..   ...  ...  ...   ...  ...  ...
# 12332  Žarko Čabarkapa  24  GSW  PF  61   0   8.3  1.1  2.9  .385  ...  0.6
# 9939    Željko Rebrača  29  DET   C  74   4  15.9  2.6  5.1  .505  ...  1.1
# 10441   Željko Rebrača  30  DET   C  30  12  16.3  2.7  4.8  .552  ...  0.9
# 11647   Željko Rebrača  32  LAC   C  58   2  16.0  2.3  4.0  .568  ...  0.8
# 12260   Željko Rebrača  33  LAC   C  29   2  14.2  1.8  3.3  .542  ...  0.4
#
#        DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
players = players[~players["Player"].str.contains("Player")]

# %%
players = players[~players["Player"].str.contains("League Average")]

# %%
players
# Out:
#                 Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  ORB  \
# 2110        A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  2.0
# 2405        A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  2.7
# 2797        A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  3.0
# 3215        A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  3.1
# 3670        A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  3.2
# ...                ...  ..  ...  ..  ..  ..   ...  ...  ...   ...  ...  ...
# 12332  Žarko Čabarkapa  24  GSW  PF  61   0   8.3  1.1  2.9  .385  ...  0.6
# 9939    Željko Rebrača  29  DET   C  74   4  15.9  2.6  5.1  .505  ...  1.1
# 10441   Željko Rebrača  30  DET   C  30  12  16.3  2.7  4.8  .552  ...  0.9
# 11647   Željko Rebrača  32  LAC   C  58   2  16.0  2.3  4.0  .568  ...  0.8
# 12260   Željko Rebrača  33  LAC   C  29   2  14.2  1.8  3.3  .542  ...  0.4
#
#        DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
combined
# Out:
#                Player Age Team Pos   G  GS    MP   FG  FGA   FG%  ...  AST  \
# 0          A.C. Green  22  LAL  PF  82   1  18.8  2.5  4.7  .539  ...  0.7
# 1          A.C. Green  23  LAL  PF  79  72  28.4  4.0  7.4  .538  ...  1.1
# 2          A.C. Green  24  LAL  PF  82  64  32.1  3.9  7.8  .503  ...  1.1
# 3          A.C. Green  25  LAL  PF  82  82  30.6  4.9  9.2  .529  ...  1.3
# 4          A.C. Green  26  LAL  PF  82  82  33.0  4.7  9.8  .478  ...  1.1
# ...               ...  ..  ...  ..  ..  ..   ...  ...  ...   ...  ...  ...
# 19066  Željko Rebrača  29  DET   C  74   4  15.9  2.6  5.1  .505  ...  0.5
# 19067  Željko Rebrača  30  DET   C  30  12  16.3  2.7  4.8  .552  ...  0.3
# 19068  Željko Rebrača  31  ATL   C  24   2  11.4  1.4  3.2  .442  ...  0.3
# 19069  Željko Rebrača  32  LAC   C  58   2  16.0  2.3  4.0  .568  ...  0.4
# 19070  Željko Rebrača  33  LAC   C  29   2  14.2  1.8  3.3  .542  ...  0.3
#
#        STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max Share
# ...

# %%
stats.to_csv("temp4.csv")

# %%
stats = stats[:-1]

# %%
stats.to_csv("stats.csv")

# %%
stats = pd.read_csv("stats.csv")

# %%
stats
# Out:
#                     Player   Age Team Pos     G    GS    MP   FG   FGA    FG%  \
# 0              Art Collins  26.0  ATL  SG  29.0   0.0  13.6  1.2   3.4  0.354
# 1            Charlie Criss  32.0  ATL  PG  66.0   0.0  25.9  3.3   7.3  0.454
# 2            Craig Shelton  23.0  ATL  SF  55.0   0.0  10.7  1.8   4.0  0.457
# 3           Dan Roundfield  27.0  ATL  PF  63.0   0.0  33.8  6.8  12.8  0.527
# 4            Eddie Johnson  25.0  ATL  SG  75.0   0.0  35.9  7.6  15.1  0.504
# ...                    ...   ...  ...  ..   ...   ...   ...  ...   ...    ...
# 18952    Marvin Bagley III  24.0  WAS   C  50.0  25.0  21.1  4.8   8.2  0.586
# 18953  Patrick Baldwin Jr.  21.0  WAS  SF  38.0   7.0  13.0  1.6   4.1  0.381
# 18954       Richaun Holmes  30.0  WAS   C  40.0  10.0  13.9  2.1   3.7  0.558
# 18955     Tristan Vukcevic  20.0  WAS   C  10.0   4.0  15.3  2.9   6.7  0.433
# 18956           Tyus Jones  27.0  WAS  PG  66.0  66.0  29.3  4.9  10.1  0.489
#
# ...

# %%
del stats["Unnamed: 0.1"]

# %%
stats.fillna(0, inplace=True)

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")
# Out:
# C:\Users\salya\AppData\Local\Temp\ipykernel_12456\3865212684.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Age        float64
# Team        object
# Pos         object
# G          float64
# GS         float64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Tm          object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats["GB"].unique()
# Out:
# array(['29.0', '13.0', '8.0', '10.0', '25.0', '7.0', '0', '4.0', '11.0',
#        '18.0', '14.0', '26.0', '12.0', '2.0', '28.0', '27.0', '17.0',
#        '15.0', '33.0', '46.0', '6.0', '22.0', '16.0', '20.0', '21.0',
#        '3.0', '9.0', '1.0', '19.0', '5.0', '23.0', '12.5', '35.0', '31.0',
#        '32.0', '41.0', '24.0', '39.0', '45.0', '37.0', '36.0', '38.0',
#        '4.5', '30.0', '40.0', '43.0', '25.5', '44.0', '42.0', '2.5',
#        '51.0', '34.0', '20.5', '32.5', '48.0', '53.0', '52.0', '3.5',
#        '56.0', '10.5', '47.0', '11.5', '22.5', '1.5', '50.0', '21.5',
#        '18.5'], dtype=object)

# %%
stats["GB"] = stats["GB"].str.replace("—", "0")

# %%
stats.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = stats[stats["G"] > 70].sort_values("PTS", ascending=False).head(10)

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
stats.groupby("Year").apply(lambda x:
